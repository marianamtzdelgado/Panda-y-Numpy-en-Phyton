# %%
import pandas as pd

# // a. Extraer la información del archivo. //

    # Ruta del archivo

file_path = ('/content/drive/MyDrive/Panda y Numpy en Python/country_vaccinations.csv')

    # Cargar el archivo CSV en un DataFrame
df = pd.read_csv(file_path)
print(df.head())

# // b. Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones puedes realizar con cada una de ellas, asegurándote que las columnas con fechas sean del tipo datetime64. //
print(df.info())

  # Columnas con fechas sean del tipo datetime64

df['date'] = pd.to_datetime(df['date'])

print("\nTipos de datos después de convertir fechas tipo datetime64:")
print(df.dtypes)

# // c. Determinar la cantidad de vacunas aplicadas de cada compañía (con base en cómo lo reporta cada país en la columna vaccines, en otras palabras, agrupe por vaccines y realice la sumatoria).

vacunas_por_compania = df.groupby('vaccines')['total_vaccinations'].sum()
print("\nCantidad de vacunas aplicadas por compañía:")
print(vacunas_por_compania)

# // d. Obtener la cantidad de vacunas aplicadas en todo el mundo. //
total_vacunas_mundo = df['total_vaccinations'].sum()
print("\nTotal de vacunas aplicadas en todo el mundo:", total_vacunas_mundo)

# // e. Calcular el promedio de vacunas aplicadas por país.  //
promedio_vacunas_por_pais = df.groupby('country')['total_vaccinations'].mean()
print("\nPromedio de vacunas aplicadas por país:")
print(promedio_vacunas_por_pais)

# // f. Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo. //
vacunas_29_enero = df[df['date'] == '2021-01-29']['total_vaccinations'].sum()
print("\nVacunas aplicadas el 29 de enero de 2021 en todo el mundo:", vacunas_29_enero)

# // g. Crear un dataframe nuevo denominado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_raw.   //
df['diferencias'] = df['daily_vaccinations'] - df['daily_vaccinations_raw']
conDiferencias = df.copy()

# // g. Obtener el periodo de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua. Requerimiento h: Periodo de tiempo entre la fecha más reciente y la más antigua //
fecha_mas_reciente = df['date'].max()
fecha_mas_antigua = df['date'].min()
periodo_tiempo = fecha_mas_reciente - fecha_mas_antigua
print("\nPeríodo de tiempo entre la fecha más reciente y la más antigua:", periodo_tiempo)

# // h. Obtener el periodo de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua. //
df['canVac'] = df['vaccines'].str.split(',').str.len()
conCantidad = df.copy()

# // j. Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020. //
antes_20_dic = df[df['date'] < '2020-12-20']
antes20 = antes_20_dic.copy()

# // k. Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado la vacuna Pfizer. //
pfizer = df[df['vaccines'].str.contains('Pfizer')]

# // l. Almacenar los dataframes generados (conDiferencias, conCantidad, antes20 y pfizer) en un archivo de Excel denominado resultadosReto.xlsx, donde cada dataframe ocupe una hoja diferente. Se recomienda ver la documentación de pd.ExcelWriter. //
with pd.ExcelWriter('resultadosReto.xlsx') as writer:
    conDiferencias.to_excel(writer, sheet_name='conDiferencias', index=False)
    conCantidad.to_excel(writer, sheet_name='conCantidad', index=False)
    antes20.to_excel(writer, sheet_name='antes20', index=False)
    pfizer.to_excel(writer, sheet_name='pfizer', index=False)

print("\n¡Proceso completado! Los resultados se han guardado en el archivo resultadosReto.xlsx.")
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  22/02/2021                 0.0                0.0
# 1  Afghanistan      AFG  23/02/2021                 NaN                NaN
# 2  Afghanistan      AFG  24/02/2021                 NaN                NaN
# 3  Afghanistan      AFG  25/02/2021                 NaN                NaN
# 4  Afghanistan      AFG  26/02/2021                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  object
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
#  11  daily_vaccinations_per_million       86213 non-null  float64
#  12  vaccines                             86512 non-null  object
#  13  source_name                          86512 non-null  object
#  14  source_website                       86512 non-null  object
# dtypes: float64(9), object(6)
# memory usage: 9.9+ MB
# None
# <ipython-input-26-b8c6c59a5d09>:18: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['date'] = pd.to_datetime(df['date'])
# Tipos de datos después de convertir fechas tipo datetime64:
# country                                        object
# iso_code                                       object
# date                                   datetime64[ns]
# total_vaccinations                            float64
# people_vaccinated                             float64
# people_fully_vaccinated                       float64
# daily_vaccinations_raw                        float64
# daily_vaccinations                            float64
# total_vaccinations_per_hundred                float64
# people_vaccinated_per_hundred                 float64
# people_fully_vaccinated_per_hundred           float64
# daily_vaccinations_per_million                float64
# vaccines                                       object
# source_name                                    object
# source_website                                 object
# dtype: object
#
# Cantidad de vacunas aplicadas por compañía:
# vaccines
# Abdala, Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Soberana02, Sputnik Light, Sputnik V                            1.784348e+08
# Abdala, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                            1.791450e+10
# Abdala, Sinopharm/Beijing, Sinovac, Soberana02, Sputnik Light, Sputnik V                                                      4.228568e+08
# Abdala, Soberana Plus, Soberana02                                                                                             6.405166e+09
# COVIran Barekat, Covaxin, FAKHRAVAC, Oxford/AstraZeneca, Razi Cov Pars, Sinopharm/Beijing, Soberana02, SpikoGen, Sputnik V    1.069480e+10
#                                                                                                                                   ...
# Pfizer/BioNTech, Sinovac, Turkovac                                                                                            3.392310e+10
# Pfizer/BioNTech, Sputnik V                                                                                                    3.863380e+06
# QazVac, Sinopharm/Beijing, Sputnik V                                                                                          3.585429e+09
# Sinopharm/Beijing                                                                                                             3.080671e+07
# Sinopharm/Beijing, Sputnik V                                                                                                  6.451243e+08
# Name: total_vaccinations, Length: 84, dtype: float64
#
# Total de vacunas aplicadas en todo el mundo: 2002854013761.0
#
# Promedio de vacunas aplicadas por país:
# country
# Afghanistan          2.566118e+06
# Albania              1.191695e+06
# Algeria              9.956086e+06
# Andorra              5.827721e+04
# Angola               6.074066e+06
#                          ...
# Wales                4.132861e+06
# Wallis and Futuna    9.142925e+03
# Yemen                4.794049e+05
# Zambia               1.048484e+06
# Zimbabwe             4.181618e+06
# Name: total_vaccinations, Length: 223, dtype: float64
#
# Vacunas aplicadas el 29 de enero de 2021 en todo el mundo: 82952931.0
#
# Período de tiempo entre la fecha más reciente y la más antigua: 482 days 00:00:00
#
# ¡Proceso completado! Los resultados se han guardado en el archivo resultadosReto.xlsx.
